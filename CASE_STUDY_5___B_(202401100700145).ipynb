# %% [markdown]
# <a href="https://colab.research.google.com/github/Ram896097/CASE-STUDY-5/blob/main/CASE_STUDY_5___B_(202401100700145).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ✅ Step 2: Upload Excel file manually (if not using Google Drive)
from google.colab import files
uploaded = files.upload()  # Select your Marks.xlsx file here

# ✅ Step 3: Read Excel file
file_path = list(uploaded.keys())[0]  # Gets the uploaded filename
MAX_MARKS = 15
# Explicitly specify the engine for read_excel
df = pd.read_excel(file_path, engine='openpyxl') # Added engine='openpyxl' to handle .xlsx files

# ✅ Step 4: Calculate percentage
df['Percentage'] = (df['Marks'] / MAX_MARKS) * 100

# ✅ Step 5: Categorize students
greater_75 = df[df['Percentage'] > 75]
between_60_75 = df[(df['Percentage'] >= 60) & (df['Percentage'] <= 75)]
less_60 = df[df['Percentage'] < 60]

# ✅ Step 6: Print categorized data
print("🔷 Students with >75%:\n", greater_75)
print("\n🔶 Students with 60%-75%:\n", between_60_75)
print("\n🔻 Students with <60%:\n", less_60)

# ✅ Step 7: Plot Histogram
plt.figure(figsize=(8, 5))
plt.hist(df['Percentage'], bins=range(0, 101, 5), edgecolor='black', color='blue')
plt.xlabel('Percentage')
plt.ylabel('Number of Students')
plt.title('Histogram Plot')
plt.grid(True)
plt.show()

# ✅ Step 8: Plot Scatter Plot
plt.figure(figsize=(8, 5))
plt.scatter(df['Name'], df['Percentage'], color='green', edgecolor='black')
plt.xlabel('Students')
plt.ylabel('Percentage')
plt.title('Scatter Plot')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
#      <input type="file" id="files-285d9089-651c-45b0-bea7-73b77ea5b699" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-285d9089-651c-45b0-bea7-73b77ea5b699">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
